# %%
# define how many to check, don't check too many simutaneously or your computer will crash
number_of_users_checked_simutaneously = 5
number_of_loops = 1

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import scripts.following as Following
import scripts.followers as Followers
import networkx as nx

from scripts.config_zlisto import *

# %%
# read tweets and identify users
fname = f"data/final_project_tweets.db"

conn = sqlite3.connect(fname)
df = pd.read_sql_query("SELECT * FROM tweet", conn)

screen_names = df.screen_name.value_counts().to_frame().reset_index()['index'].tolist()

# %%
# pull following network
start = 0
end = start + number_of_users_checked_simutaneously

for i in range(number_of_loops):
    # read existing data
    df = pd.read_excel('follower_network.xlsx')
    df = df[['screen_name', 'following']]
    existing_screen_names = df.screen_name.tolist()
    
    # remove existing data from list of users to avoid duplicates
    for existing_screen_name in existing_screen_names:
        if existing_screen_name in screen_names:
            screen_names.remove(existing_screen_name)

    # pull new users
    screen_name = screen_names[start:end]
    df1 = Following.Network.multi_fetch(users=screen_name, max_count = 500)
    df = df.append(df1).drop_duplicates(subset=['screen_name'])

    df.to_excel('follower_network.xlsx')
# Out:
# ['TSchmittty', 'IfjBDqGnwvgmYAj', 'sonoftaiwan', 'AliUighur', 'Aling88188', 'AdityaSKG', 'ledzepfan400', 'SunnySu11114692', 'Monu572950195', 'kateimei', 'jin_yang', 'xChJy3J1FwvKVHv', 'climate_fact', 'AsianSocialNet', 'gaojiejie888', 'EvaTeng6', 'TheIndoreRocks', 'BoycottHegemony', 'j2AMWNHe0GrudOY', 'Wendyy2009Wendy', 'SSKM44507288', 'anand_ami', '923055105000_6', '1f8PVxouToaU0R9', 'b5kv4E6LWdqQ52d', 'IloveBush43', 'takedownevilccp', 'shujingchenhu', 'prisoner1968', 'st0nel0ver', 'tweet4852', 'chekree', 'taetaeiish', 'Kevin25253914', 'BarryDutton', 'roysopinie2', 'btscrepuscule', 'Aumnovi1', 'IcuNoItAll', 'LaiChi32153792', 'AmbiiMoore', 'realEternalSoul', 'SolomonYue', 'miraforeman', 'LovieSuki', 'JFSebastian146', 'shatinme', 'Malcolm70979013', 'WuhanVirus_2019', 'amitkr12jan', 'Lushanzilong', '5sos_Vampsjrt1d', 'HimalayaLa8', 'SusanTill8', 'Cindybab121', 'Taxuewuhen0506', 'iCoolYoSanty', 'gorbachevkhrus1', 'mcleanksm', '_James_Wilson', 'forestcui02', 'Civilianaire_IN', 'twoasianparents', 'YehCathery', 'lanzhixing2', 'The_Lunar_Times', 'DianeWang8', 'PatMcNamara43', 'MadnessDarknes1', 'kumar_ashish301', 'phoebe495524066', 'DbBourke', 'Fairbanks357', 'ActToChange', 'JimWhit35636016', 'linanfei1', 'Boller735_2', 'StPetersShadow', 'lewis0060', 'robertosansie', 'NaeemIsmeel', '223UBkPtFC9XyVv', 'waynexfwang', 'HelenHsuPsyD', 'Silence21240183', 'jessie50344442', 'Hunterwolfwang', 'WoneTone', 'FromAsh2', 'TheYappie', 'DacaiF', 'BoiseAs', 'sjaanie123', 'nevergu2019', 'qianqiu1975', 'Surfing_Yeti', 'Jianghehuhai1', 'Krazy9Kat', 'CCPVirus_XM', 'media_nuance', 'Peterconet2', 'FChicomBitches', 'soldes18', 'brightonproj', 'BudGothmog44', 'screen_tan', 'PaulaYoo', 'constitutionmd', 'hoodedpantsman', 'Sophia06230286', 'jemin_p', 'phiyaatv', 'amadorn', 'crowwrites', 'EGLetIjNIpaz7tQ', 'kimlorio24', 'freeddeplorable', 'bing41358392', 'loveme92871244', 'pinkydinky00', 'JudasPavas', 'ms_plandemic', 'UnitedPeaceColl', 'Alleninvest', 'samarthsr', 'GueffafB', 'moco_moco_phoo', '9tKMy3eg4ntUc4Z', 'BasualtoMariana', 'sarmadsalman61', 'khineainsik', 'littleS37471944', 'RaghuTanjavur', 'ckajuoykcuf', 'jun680213', 'AmericaHostage', 'LiuBaoBei1', 'nasatanukisaka', 'invisibleasians', 'Jamie80103945', 'DorisQuakenbush', 'KIN20200604', 'TheRiseOfTrump', 'BrucePollock13', 'thebostonlot', 'fair800', 'tiandiliangxin1', 'shawnarchen', 'winwin888888', 'Jeffrey45066216', 'miltorbica', 'Respond2Racism', '8wqIGH20IbdtwRS', 'toushan_Bai', 'DefenderValues', 'bridb', 'Sonic111965449', 'freekoparker', 'twiiit_sam', 'ForwardProgres6', 'mulao14', 'HLeeGator', 'og_centennial', 'AsifKha94399341', 'tatn', 'a663831230', 'totty_xio24', 'WinnieeYang', 'Afoodaficionado', 'drama_guara', 'weilaibb', 'my_igh', 'austintemple24', 'ChinaSucks8', 'LADodgersFan626', 'DannyCh83145536', 'kurtbardella', 'admz767671', 'DM69930350', 'RobertN58520057', 'Ray55723615', 'peterjustice777', 'Barbtomko1', 'JosephineFitzm1', 'its__abi', 'Dicky6427', 'BillWongLLC', 'WiththeNation', 'CinnabonMonster', 'MiamiPapers', 'zt1M5ClucPTLlLi', 'Chen1Tommy', 'Fuckthe_gravity', 'spearfishcabin1', 'FredNurf', 'rdrumx', 'Orygun4Rod', 'one10952000', 'JuanCar59512447', 'applechai4', 'RamSudar5', 'Kookoo86834620', 'Lily04471413', 'paulinepark', 'AppleLam15', 'VNP8476', 'MonsTemere', 'benshen19', 'kamesh_gadia', 'MARD_0002', 'jgionova', 'CurtisSChin', 'mcgoverntm', 'lilibeth202', 'StevennBeck1', 'x3_pikachu', 'whynotstop123', 'DrALMEIDA0001', 'RedpillEire', 'Durant9603', 'themascator1', 'Joeanthony_nyc', 'btuj9pnsBYGKeqC', 'MOVsDad', 'dharma_shastr', 'blue21sky', 'xzhlbjg64', 'Rockcmrk', 'UshaNirmala', 'CAPAC', 'OminiBrun', 'ImperfectANG3L', '4sutq8', 'longjinshi', 'Tayzar13679870', 'FireFly53647402', 'oldmoon95018663', 'ravulasandy', 'YEYU20200604a1', 'AlanTonelson', 'FlatEarthCity', 'Gislalino', 'MSN100MS46', 'Sanjog72905320', 'DEipYOiSwj8Okfd', 'AmolTikam', 'EOXO9zCujKpSmCv', 'tteco77', 'ArmanLloydSilv1', 'Akhiles86933002', 'yanhuali2', 'DarryDekens1', 'fanqieniurou', 'JudyAnd56006226', 'Gondolier9', 'Only4RM', ...

# %%
# create network ------------- no need to run anything below if just pulling data -------------------
df = pd.read_excel('follower_network.xlsx')
df = df[['screen_name', 'following']]
G = nx.DiGraph()
for index,row in df.iterrows():
    u = row.screen_name
    G.add_node(u)
    for v in row.following:
        if v in df.screen_name.tolist():
            G.add_edge(v,u)
            
print(f"Network has {G.number_of_nodes()} nodes, {G.number_of_edges()} edges")
# Out:
# Network has 25 nodes, 0 edges

# %%
# save and load network
fname = 'data/network_following.pickle'
nx.write_gpickle(G,fname)
G = nx.read_gpickle(fname)

# %%
# draw network
def draw_network_pos(G,pos,title_str):
    node_size = 100
    node_color = "pink"
    width = 0.5
    edge_color = "white"
    bg_color = "black"

    #2 points  drawing network with directed layout 
    fig = plt.figure(figsize= (8,6))
    plt.subplot(1,1,1)
    nx.draw(G, width=width,pos=pos ,node_color=node_color,
            edge_color=edge_color,node_size=node_size,
            connectionstyle='arc3',with_labels=True,font_color = 'white')
    plt.title(title_str,color = "white")
    fig.set_facecolor(bg_color)
    plt.show()    
    return 1

pos = nx.kamada_kawai_layout(G)
draw_network_pos(G,pos,"Biden Following Network")
# Out:
# 1
